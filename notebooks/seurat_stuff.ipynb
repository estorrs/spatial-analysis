# %%
library(Seurat)
# library(SeuratData)
library(ggplot2)
library(patchwork)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
rds = readRDS('../data/breast/All_breast_processed_label_transferred_anchored.rds')
rds
# Out:
# Error in readRDS("../data/breast/All_breast_processed_label_transferred_anchored.rds"): error reading from connection
# Traceback:
#
# 1. readRDS("../data/breast/All_breast_processed_label_transferred_anchored.rds")

# %%
rds@meta.data
# Out:
#                    orig.ident    nCount_Spatial nFeature_Spatial nCount_SCT
# AAACAAGTATCTCCCA-1 SeuratProject  1195           778             5615
# AAACAATCTACTAGCA-1 SeuratProject 40160          7370             7616
# AAACACCAATAACTGC-1 SeuratProject 24709          6244             7450
# AAACAGAGCGACTCCT-1 SeuratProject  1842          1020             5852
# AAACAGCTTTCAGAAG-1 SeuratProject 49222          9217             8601
# AAACAGGGTCTATATT-1 SeuratProject   566           393             5405
# AAACATTTCCCGGATT-1 SeuratProject 15438          4956             8275
# AAACCCGAACGAAATC-1 SeuratProject  5362          2590             6293
# AAACCGGGTAGGTACC-1 SeuratProject  4289          1996             6263
# AAACCGTTCGTCCAGG-1 SeuratProject 21019          5307             7558
# AAACCTAAGCAGCCGG-1 SeuratProject 11479          4489             8231
# AAACCTCATGAAGTTG-1 SeuratProject  8756          3721             7892
# ...

# %%
write.table(rds@meta.data, file="../data/brca_HT206/BRCA_206B1_seurat_annot_HandEv3_metadata.txt", quote=FALSE,
           sep="\t")

# %%
head(rds@assays$SCT@scale.data)
# Out:
#            AAACAAGTATCTCCCA-1 AAACAATCTACTAGCA-1 AAACACCAATAACTGC-1
# AL627309.1 -0.005606657       -0.07693762        -0.06060059
# AL627309.5 -0.039132741        3.95342581        -0.16383285
# LINC01409  -0.056013974       -0.28095173        -0.23127791
# LINC01128  -0.091740909        0.90006864        -0.43367209
# LINC00115  -0.022728440       -0.20671366        -0.16564739
# FAM41C     -0.006252646       -0.08384306        -0.06618141
#            AAACAGAGCGACTCCT-1 AAACAGCTTTCAGAAG-1 AAACAGGGTCTATATT-1
# AL627309.1 -0.00991921        -0.08457095         0.0001903194
# AL627309.5 -0.04901284        -0.21628863        -0.0258594765
# LINC01409  -0.06995229        -0.30358629        -0.0373130802
# LINC01128  -0.11887723        -0.57135265        -0.0555157639
# LINC00115  -0.03403774        -0.22555468        -0.0075536974
# FAM41C     -0.01098036        -0.09207213         0.0001125692
#            AAACATTTCCCGGATT-1 AAACCCGAACGAAATC-1 AAACCGGGTAGGTACC-1
# ...

# %%
length(rds@assays$SCT@scale.data)
# Out:
# [1] 74641044

# %%
rds@assays$SCT
# Out:
# Assay data with 20444 features for 3651 cells
# Top 10 variable features:
#  IGKC, IGLC2, IGHA1, IGHG1, IGLC1, JCHAIN, IGHG3, IGHM, IGLC3, IGHG4

# %%
write.table(rds@assays$SCT@scale.data, file="../data/brca_HT206/sctransform_scaled.txt", quote=FALSE,
           sep="\t")
