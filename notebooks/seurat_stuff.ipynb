# %%
library(Seurat)
# library(SeuratData)
library(ggplot2)
library(patchwork)
library(dplyr)
# Out:
# Attaching SeuratObject
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
rds = readRDS('../data/breast/All_breast_processed_label_transferred_anchored.rds')
rds
# Out:
# An object of class Seurat
# 65628 features across 60747 samples within 6 assays
# Active assay: All_Integrated_anchored_predictions (18 features, 0 variable features)
#  5 other assays present: Spatial, SCT, predictions, integrated_predictions, integrated
#  2 dimensional reductions calculated: pca, umap

# %%
rds@meta.data
# Out:
#                                    orig.ident      nCount_Spatial
# HT206B1_H8_U1_AAACAAGTATCTCCCA-1   HT206B1_H8_U1    1195
# HT206B1_H8_U1_AAACAATCTACTAGCA-1   HT206B1_H8_U1   40160
# HT206B1_H8_U1_AAACACCAATAACTGC-1   HT206B1_H8_U1   24709
# HT206B1_H8_U1_AAACAGAGCGACTCCT-1   HT206B1_H8_U1    1842
# HT206B1_H8_U1_AAACAGCTTTCAGAAG-1   HT206B1_H8_U1   49222
# HT206B1_H8_U1_AAACAGGGTCTATATT-1   HT206B1_H8_U1     566
# HT206B1_H8_U1_AAACATTTCCCGGATT-1   HT206B1_H8_U1   15438
# HT206B1_H8_U1_AAACCCGAACGAAATC-1   HT206B1_H8_U1    5362
# HT206B1_H8_U1_AAACCGGGTAGGTACC-1   HT206B1_H8_U1    4289
# HT206B1_H8_U1_AAACCGTTCGTCCAGG-1   HT206B1_H8_U1   21019
# HT206B1_H8_U1_AAACCTAAGCAGCCGG-1   HT206B1_H8_U1   11479
# HT206B1_H8_U1_AAACCTCATGAAGTTG-1   HT206B1_H8_U1    8756
# HT206B1_H8_U1_AAACGAAGAACATACC-1   HT206B1_H8_U1    2189
# HT206B1_H8_U1_AAACGCCCGAGATCGG-1   HT206B1_H8_U1    5331
# HT206B1_H8_U1_AAACGGGCGTACGGGT-1   HT206B1_H8_U1    2240
# ...

# %%
rds@assays$All_Integrated_anchored_predictions@data
# Out:
#             HT206B1_H8_U1_AAACAAGTATCTCCCA-1 HT206B1_H8_U1_AAACAATCTACTAGCA-1
# CD8-T       0.002780945                      0.00000000
# Endothelial 0.051926712                      0.00000000
# CAF         0.334457723                      0.11901850
# Her2-Tumor  0.023914939                      0.04727642
# Normal-duct 0.198311396                      0.07135680
# NK          0.000000000                      0.00000000
# Mono-Macro  0.000000000                      0.00000000
# Treg        0.000000000                      0.00000000
# CD4-T       0.000000000                      0.00000000
# DC          0.000000000                      0.00000000
# NKT-cells   0.000000000                      0.00000000
# B           0.006112672                      0.00000000
# Plasma      0.000000000                      0.00000000
# Mast        0.000000000                      0.00000000
# LumB-Tumor  0.302924823                      0.24442289
# ...

# %%
write.table(rds@meta.data, file="../data/breast/All_breast_processed_label_transferred_anchored_metadata.txt",
            quote=FALSE, sep="\t")

# %%
write.table(rds@assays$All_Integrated_anchored_predictions@data,
            file="../data/breast/All_breast_processed_label_transferred_anchored_predictions.txt",
            quote=FALSE, sep="\t")

# %%
head(rds@assays$SCT@scale.data)
# Out:
#           HT206B1_H8_U1_AAACAAGTATCTCCCA-1 HT206B1_H8_U1_AAACAATCTACTAGCA-1
# LINC02593 -0.1730650                       -0.1604516
# SAMD11    -0.2395683                       -0.3294068
# HES4      -0.7475212                        2.2366054
# ISG15     -1.1657397                        1.0445171
# TNFRSF18  -0.3450962                       -0.5285978
# TNFRSF4   -0.5032937                       -0.7652391
#           HT206B1_H8_U1_AAACACCAATAACTGC-1 HT206B1_H8_U1_AAACAGAGCGACTCCT-1
# LINC02593 -0.1977117                       -0.1809095
# SAMD11    -0.3560339                       -0.2559672
# HES4       0.2717639                        0.5079360
# ISG15      1.4308085                        0.2017748
# TNFRSF18   2.4367917                       -0.3705168
# TNFRSF4    0.3080488                        4.1309183
#           HT206B1_H8_U1_AAACAGCTTTCAGAAG-1 HT206B1_H8_U1_AAACAGGGTCTATATT-1
# LINC02593 -0.13304856                      -0.1615201
# ...

# %%
length(rds@assays$SCT@scale.data)
# Out:
# [1] 182241000

# %%
rds@assays$SCT
# Out:
# SCTAssay data with 25973 features for 60747 cells, and 6 SCTModel(s)
# First 10 features:
#  AL627309.1, AL627309.5, AP006222.2, AL732372.1, AL669831.2, LINC01409,
# FAM87B, LINC01128, LINC00115, FAM41C

# %%
write.table(rds@assays$SCT@scale.data,
            file="../data/breast/All_breast_processed_label_transferred_anchored_sctransform.txt", quote=FALSE,
           sep="\t")
